# %%
# segmentationTest.py
"""
CSCI 332
Esther Lyon Delsordo
Software Assignment #2
Due December 10, 2022

Implement Ford-Fulkerson Alg and use it to implement the image
segmentation algorithm from Kleinberg-Tardos 7.10

Test script for segmentationClass.py
"""

# Import numpy and pyplot
import numpy as np
import matplotlib.pyplot as plt

# Import my image segmentation class
import segmentationClass

# load a test image FIXME
# I = plt.imread("Louisfjellet25pixel.jpg")

# build test image FIXME
# 3 x 3 with two red pixels, others valued zero
I = np.zeros([3, 3, 3])
I[2, 2, 0] = 128
I[1, 2, 0] = 128

# Make an image segmentation object
# set segmentation object params inline FIXME
sc = segmentationClass.segmentationClass(
    p0=1,  # neigbor penalty
    x_a=np.array([2, 2]),  # Foreground pixel position
    x_b=np.array([0, 0]),  # Background pixel
)

# segment the image
newI = sc.segmentImage(I)

# Plot results
fig, axs = plt.subplots(1, 2)
fig.suptitle("Input and segmentation")
axs[0].imshow(I.astype(np.uint8), interpolation="nearest")
axs[0].set_title("Input image")

# scale 0s and 1s in output image to 0 or 255
axs[1].imshow(255 * newI.astype(np.uint8), interpolation="nearest", cmap = "Greys")
axs[1].set_title("Binary segmentation")
plt.show()
# Out:
# newNode.pos:  [0 0]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [0 1]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [0 2]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [1 0]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [1 1]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [1 2]
# newNode.rgb:  [128   0   0]
# newNode.pos:  [2 0]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [2 1]
# newNode.rgb:  [0 0 0]
# newNode.pos:  [2 2]
# newNode.rgb:  [128   0   0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [128   0   0]
# G[s].capacities[node.key] [442, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [128   0   0]
# G[t].capacities[node.key] [0, 314]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [128   0   0]
# node.capacities[G[s].key] [0, 314]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [128   0   0]
# node.capacities[G[t].key] [442, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# G[s].capacities[node.key] [314, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# G[t].capacities[node.key] [0, 442]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [0 0 0]
# node.capacities[G[s].key] [0, 442]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [0 0 0]
# node.capacities[G[t].key] [314, 0]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [128   0   0]
# G[s].capacities[node.key] [442, 0]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [128   0   0]
# G[t].capacities[node.key] [0, 314]
# G[x_b_key].rgb:  [0 0 0]
# G[x].rgb [128   0   0]
# node.capacities[G[s].key] [0, 314]
# G[x_a_key].rgb:  [128   0   0]
# G[x].rgb [128   0   0]
# node.capacities[G[t].key] [442, 0]
# Residual src.edgesOut [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Gf[0].pos:  [0 0]
# Gf[0].rgb:  [0 0 0]
# G[o].capacities:  {0: [1, 1], 1: [1, 1], 3: [1, 1], 4: [1, 1], 10: [0, 442], 9: [314, 0]}
# Gf[0].capacities:  {0: [1, 1], 1: [1, 1], 3: [1, 1], 4: [1, 1], 10: [0, 442], 9: [314, 0]}
# i:  0
# j 0
# Gf[i].capacities[j][0] 1
# Gf[i].capacities[j][0] == 0 False
# G[i].capacities[j][0] > 0 True
# visited[i] False
# i:  0
# j 1
# Gf[i].capacities[j][0] 1
# Gf[i].capacities[j][0] == 0 False
# G[i].capacities[j][0] > 0 True
# visited[i] False
# i:  0
# j 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [1], in <cell line: 39>()
#      32 sc = segmentationClass.segmentationClass(
#      33     p0=1,  # neigbor penalty
#      34     x_a=np.array([2, 2]),  # Foreground pixel position
#      35     x_b=np.array([0, 0]),  # Background pixel
#      36 )
#      38 # segment the image
# ---> 39 newI = sc.segmentImage(I)
#      41 # Plot results
#      42 fig, axs = plt.subplots(1, 2)
#
# File ~\Documents\csci332\segmentationClass.py:184, in segmentationClass.segmentImage(self, I)
#     182 print("i: ", i)
#     183 print("j", j)
# --> 184 print("Gf[i].capacities[j][0]", Gf[i].capacities[j][0])
#     185 print("Gf[i].capacities[j][0] == 0", Gf[i].capacities[j][0] == 0)
#     186 print("G[i].capacities[j][0] > 0", G[i].capacities[j][0] > 0)
#
# KeyError: 2

# %%
rgb1 = np.array([0,0,0])
rgb2 = np.array([128,0,0])
d = np.round(np.sqrt(((rgb1 - rgb2) ** 2).sum()))
print(int(442 - d))
# Out:
# 314
